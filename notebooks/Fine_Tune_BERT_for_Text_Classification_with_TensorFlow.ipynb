# %% [markdown]
# <a href="https://colab.research.google.com/github/sergfer26/transformer-studio/blob/main/notebooks/Fine_Tune_BERT_for_Text_Classification_with_TensorFlow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
